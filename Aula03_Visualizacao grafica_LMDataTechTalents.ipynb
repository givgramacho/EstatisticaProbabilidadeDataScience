# %% [markdown]
# # ADA - LM Tech Data Talents 2022
#
# # Curso de Estatística  Let´s Code.
#
# ## Givanildo de Sousa Gramacho
#
#
# ### Aula03 - Visualização gráfica
#
# Visite [Aula 03 - Visualização gráfica Letscode](https://cursos.letscode.com.br/curso-digital/604d0397-08a9-4dbd-9dbf-cb68a03cb29b/modulo/659f5188-4f3c-4502-9d23-f8e580c452de/topico/72a1d20d-1ec3-4726-baa2-0618f517f955) para mais informações.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Gráfico coluna  serve para medir frequência de um dado categórico.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Visualizar a proporção do dados e tem poucas categórias e verificar a relação entre elas.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ajuda a ver uma distribuição de frequência entre alguma coisa.
# ![image.png](attachment:image.png)

# %% [markdown]
# As idades vai variar entre 6  a 89 anos
#
# - Vantagem e conseguir ver os
# - limites superior ls
# - limite inferior  li
# - 1o quartil Q1
# - 2o quartil Q2 = Mediana dos dados
# - 3o quanrtil Q3
# - Fora do quartil são os outlier fora
# ![image.png](attachment:image.png)

# %% [markdown]
# - Relação entre peso e altura
# - Ver a relação quanto maior o peso maior a altura
# - Interpretação dos dados rápida e clara.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### Resposta:
# - O gráfico contém Título, eixo, rótulos, legenda, fonte e barras/linhas.
# - Esse é um gráfico de barras junto com um gráfico de linhas e se refere ao número de casos de mortes pela covid no Brasil entre 17/03/2020 e 12/05/2020.
# - O ocorreu o maior pico de mortos em 12/maio/2020 com aproximadamente 900 mortos.
# - Mostra que o número de casos e mortes aumentam ao longo do tempo.
